# %% [markdown]
# ## Multiple Logistic Regression

# %% [markdown]
# Import Pandas and scikit-learn dependencies, particularly the `LogisticRegression` linear model.

# %%
import pandas as pd
import numpy as np 
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Read and display the five columns of data, and save to a `df` variable.

# %%
df = pd.read_csv('https://bit.ly/3SMHvPa', delimiter=",")
df
# Out:
#     RAIN  LIGHTNING  CLOUDY  TEMPERATURE  GOOD_WEATHER_IND
# 0      0          1       1           74                 0
# 1      0          0       0           69                 1
# 2      1          0       1           58                 0
# 3      0          0       0           71                 1
# 4      0          0       0           73                 1
# 5      0          1       1           80                 0
# 6      0          1       1           74                 0
# 7      0          0       0           73                 1
# 8      1          0       1           79                 0
# 9      0          0       1           72                 1
# 10     0          1       1           66                 0
# 11     1          1       1           63                 0
# 12     0          0       1           70                 1
# 13     1          1       1           83                 0
# 14     0          1       1           66                 0
# 15     0          0       1           72                 1
# 16     1          1       1           74                 0
# 17     1          0       1           76                 0
# 18     0          0       0           74                 1
# 19     0          0       1           74                 1
# 20     0          0       1           73                 1
# 21     0          0       0           76                 1
# 22     0          0       1           77                 0
# 23     0          1       1           73                 0
# 24     0          1       1           81                 0
# 25     1          0       1           62                 0
# 26     0          0       0           77                 1
# 27     0          0       0           77                 1
# 28     1          0       1           71                 0
# 29     1          0       1           79                 0
# 30     1          0       1           65                 0
# 31     1          0       1           67                 0
# 32     1          1       1           59                 0
# 33     0          1       1           58                 0
# 34     0          1       1           65                 0
# 35     0          1       1           61                 0
# 36     0          0       0           85                 0
# 37     1          0       1           84                 0
# 38     1          0       1           59                 0
# 39     0          0       0           88                 0
# 40     0          0       0           91                 0
# 41     0          0       1           90                 0
# 42     1          0       1           81                 0
# 43     0          0       0           94                 0
# 44     0          0       0           96                 0
# 45     0          0       1           72                 1
# 46     0          0       0           99                 0
# 47     0          0       1           89                 0
# 48     1          1       1           71                 0
# 49     0          0       0          101                 0

# %% [markdown]
# Extract the independent `X` variables and dependent `Y` variable as two separate datasets.

# %%
X = df.values[:, :-1]
Y = df.values[:, -1]

# %% [markdown]
# Create the `LogisticRegression` model and train it with the `X` and `Y` data. To keep things simple, be sure to set `penalty` to `none` to maximize fitting.

# %%
model = LogisticRegression(penalty='none')
model.fit(X, Y)
# Out:
# LogisticRegression(penalty='none')

# %% [markdown]
# Print the coefficient values.

# %%
bx = model.coef_
b0 = model.intercept_
print(b0, bx)
# Out:
# [769.25074529] [[-1849.68755115 -1765.18752495   -62.67028868    -9.35164931]]

# %%
# Make a prediction on whether an observation is good weather
# rain, lightning, cloudy, temperature
prediction = model.predict_proba([[0, 0, 1, 76]])
print("GOOD WEATHER PREDICTION: ", prediction)
# Out:
# GOOD WEATHER PREDICTION:  [[0.98440199 0.01559801]]
